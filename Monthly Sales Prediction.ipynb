# %% [markdown]
# # Monthly Sales Prediction using ARIMA model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-Statement/Objective:" data-toc-modified-id="Problem-Statement/Objective:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem Statement/Objective:</a></span></li><li><span><a href="#Importing-Packages" data-toc-modified-id="Importing-Packages-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Importing Packages</a></span></li><li><span><a href="#Importing-Store-Dataset" data-toc-modified-id="Importing-Store-Dataset-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Importing Store Dataset</a></span><ul class="toc-item"><li><span><a href="#Description-of-the-dataset:" data-toc-modified-id="Description-of-the-dataset:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Description of the dataset:</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Sales-Data-Distribution" data-toc-modified-id="Sales-Data-Distribution-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Sales Data Distribution</a></span></li><li><span><a href="#Data-Preparation" data-toc-modified-id="Data-Preparation-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Data Preparation</a></span></li><li><span><a href="#Yearly-Sales-during-2013---2017" data-toc-modified-id="Yearly-Sales-during-2013---2017-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Yearly Sales during 2013 - 2017</a></span></li><li><span><a href="#10-Highest-YoY-Monthly-Sales-trend" data-toc-modified-id="10-Highest-YoY-Monthly-Sales-trend-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>10 Highest YoY Monthly Sales trend</a></span></li><li><span><a href="#Quarterly-Sales-Trend" data-toc-modified-id="Quarterly-Sales-Trend-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Quarterly Sales Trend</a></span></li><li><span><a href="#Top-10-Most-Expensive-Items-Sold" data-toc-modified-id="Top-10-Most-Expensive-Items-Sold-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Top 10 Most Expensive Items Sold</a></span></li><li><span><a href="#Which-Store-has-the-highest-Sales?" data-toc-modified-id="Which-Store-has-the-highest-Sales?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Which Store has the highest Sales?</a></span></li><li><span><a href="#How-many-items-were-sold-in-each-Quarter/Year?" data-toc-modified-id="How-many-items-were-sold-in-each-Quarter/Year?-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>How many items were sold in each Quarter/Year?</a></span></li><li><span><a href="#Total-selling-Price-of-each-item" data-toc-modified-id="Total-selling-Price-of-each-item-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Total selling Price of each item</a></span></li><li><span><a href="#How-many-items-were-sold-every-year?" data-toc-modified-id="How-many-items-were-sold-every-year?-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>How many items were sold every year?</a></span></li></ul></li><li><span><a href="#Time-Series-Analysis" data-toc-modified-id="Time-Series-Analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Time Series Analysis</a></span><ul class="toc-item"><li><span><a href="#Checking-Trend-Component" data-toc-modified-id="Checking-Trend-Component-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Checking Trend Component</a></span></li><li><span><a href="#Decomposition" data-toc-modified-id="Decomposition-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Decomposition</a></span></li><li><span><a href="#Stationarity-Check" data-toc-modified-id="Stationarity-Check-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Stationarity Check</a></span><ul class="toc-item"><li><span><a href="#Rolling-Statistics-Methodology" data-toc-modified-id="Rolling-Statistics-Methodology-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Rolling Statistics Methodology</a></span></li><li><span><a href="#ADF(Augmented-Dickey-Fuller)-Test" data-toc-modified-id="ADF(Augmented-Dickey-Fuller)-Test-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>ADF(Augmented Dickey-Fuller) Test</a></span></li></ul></li><li><span><a href="#Data-Transformation-to-achieve-Stationarity" data-toc-modified-id="Data-Transformation-to-achieve-Stationarity-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Data Transformation to achieve Stationarity</a></span><ul class="toc-item"><li><span><a href="#Log-Scale-Transformation" data-toc-modified-id="Log-Scale-Transformation-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Log Scale Transformation</a></span></li><li><span><a href="#Log-Scale---Moving-Average-Transformation" data-toc-modified-id="Log-Scale---Moving-Average-Transformation-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Log Scale - Moving Average Transformation</a></span></li><li><span><a href="#Exponential-Decay-Transformation" data-toc-modified-id="Exponential-Decay-Transformation-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Exponential Decay Transformation</a></span></li><li><span><a href="#Time-Shift-Transformation" data-toc-modified-id="Time-Shift-Transformation-5.4.4"><span class="toc-item-num">5.4.4&nbsp;&nbsp;</span>Time Shift Transformation</a></span></li></ul></li></ul></li><li><span><a href="#Building-Models" data-toc-modified-id="Building-Models-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Building Models</a></span><ul class="toc-item"><li><span><a href="#AR-Model" data-toc-modified-id="AR-Model-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>AR Model</a></span></li><li><span><a href="#ARMA-Model" data-toc-modified-id="ARMA-Model-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>ARMA Model</a></span></li><li><span><a href="#ARIMA-Model" data-toc-modified-id="ARIMA-Model-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>ARIMA Model</a></span></li><li><span><a href="#Prediction-&amp;-Reverse-transformations-of-fittedvalues" data-toc-modified-id="Prediction-&amp;-Reverse-transformations-of-fittedvalues-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Prediction &amp; Reverse transformations of fittedvalues</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# ## Problem Statement/Objective:
#
# The objective of this project is to predict 3 months of item-level sales data at different store locations.

# %% [markdown]
# ## Importing Packages

# %%
import numpy as np                     

import pandas as pd
pd.set_option('mode.chained_assignment', None)      # To suppress pandas warnings.
pd.set_option('display.max_colwidth', None)           # To display all the data in each column
pd.options.display.max_columns = 50                 # To display every column of the dataset in head()

import itertools       #provides various functions that work on iterators to produce complex iterators

import warnings
warnings.filterwarnings('ignore')                   # To suppress all the warnings in the notebook.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)      # To apply seaborn styles to the plots.

import statsmodels.tsa.api as smt

# %% [markdown]
# ## Importing Store Dataset

# %%
df_Store = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-3/master/Projects/Store_Item_demand_forecast.csv')
df_Store.head()
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %% [markdown]
# ### Description of the dataset:
#
# Data fields<br>
# •	date - Date of the sale data. There are no holiday effects or store closures.<br>
# •	store - Store ID<br>
# •	item - Item ID<br>
# •	sales - Number of items sold at a particular store on a particular date.<br>

# %%
df_Store.shape
# Out:
# (913000, 4)

# %%
df_Store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    913000 non-null  object
#  1   store   913000 non-null  int64
#  2   item    913000 non-null  int64
#  3   sales   913000 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 27.9+ MB

# %%
df_Store.isnull().sum()
# Out:
# date     0
# store    0
# item     0
# sales    0
# dtype: int64

# %% [markdown]
# ***Observation:***
#
# - This dataset consists of 913k rows and 4 columns with 3 numerical and 1 object data types.
# - This is a clean dataset with no null values.

# %%
df_Store.describe()
# Out:
#                store           item          sales
# count  913000.000000  913000.000000  913000.000000
# mean        5.500000      25.500000      52.250287
# std         2.872283      14.430878      28.801144
# min         1.000000       1.000000       0.000000
# 25%         3.000000      13.000000      30.000000
# 50%         5.500000      25.500000      47.000000
# 75%         8.000000      38.000000      70.000000
# max        10.000000      50.000000     231.000000

# %% [markdown]
# ***Obervation:***
#
# - The *.describe()* of numerical values shows that the Stores are located in areas ranging from 1 to 10.
# - Similarly, there are ***items*** in the store ranging from 1 to 50 items in each store.
# - The Sales column is positively left skewed with median at 47 and maximum at 231. The same is depicted in the graph below.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Sales Data Distribution

# %%
sns.distplot(df_Store.sales, color="blue")

# %% [markdown]
# ### Data Preparation

# %%
#Extracting Month, Year columns from the date field and converting it to datetime format

df_Store['year'] = pd.to_datetime(df_Store['date']).dt.year
df_Store['quarter_year'] = pd.to_datetime(df_Store['date']).dt.to_period('Q')
df_Store['month_year'] = pd.to_datetime(df_Store['date']).dt.to_period('M')
df_Store.head()
# Out:
#          date  store  item  sales  year quarter_year month_year
# 0  2013-01-01      1     1     13  2013       2013Q1    2013-01
# 1  2013-01-02      1     1     11  2013       2013Q1    2013-01
# 2  2013-01-03      1     1     14  2013       2013Q1    2013-01
# 3  2013-01-04      1     1     13  2013       2013Q1    2013-01
# 4  2013-01-05      1     1     10  2013       2013Q1    2013-01

# %%
df_Store.isnull().sum()
# Out:
# date            0
# store           0
# item            0
# sales           0
# year            0
# quarter_year    0
# month_year      0
# dtype: int64

# %% [markdown]
# ### Yearly Sales during 2013 - 2017

# %%
df_Store.groupby('year')['sales'].sum().sort_values(ascending=False)
# Out:
# year
# 2017    10733740
# 2016    10357160
# 2015     9536887
# 2014     9135482
# 2013     7941243
# Name: sales, dtype: int64

# %%
plt.figure(figsize = (12, 6))
df_Store.groupby('year')['sales'].sum().sort_values(ascending=False).plot(kind='bar', color='b')

plt.xlabel('year', fontweight="bold", fontsize=12)
plt.ylabel('sales', fontweight="bold", fontsize=12)
plt.title('Yearly Sales during 2013 to 2017', fontweight="bold", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Yearly Sales during 2013 to 2017')

# %% [markdown]
# - 2017 shows the highest sales with 10.7mn

# %% [markdown]
# ### 10 Highest YoY Monthly Sales trend

# %%
df_Store.groupby('month_year')['sales'].sum().sort_values(ascending=False)[:10]
# Out:
# month_year
# 2017-07    1171393
# 2016-07    1138718
# 2017-06    1064624
# 2015-07    1037350
# 2017-08    1026403
# 2016-06    1022664
# 2017-05    1020686
# 2014-07     989010
# 2016-05     988730
# 2016-08     981494
# Freq: M, Name: sales, dtype: int64

# %%
plt.figure(figsize = (12, 6))
df_Store.groupby('month_year')['sales'].sum().sort_values(ascending=False)[:10].plot(kind='bar', color='g')

plt.xlabel('month_year', fontweight="bold", fontsize=12)
plt.ylabel('sales', fontweight="bold", fontsize=12)
plt.title('10 Highest YoY Monthly Sales trend', fontweight="bold", fontsize=18)
# Out:
# Text(0.5, 1.0, '10 Highest YoY Monthly Sales trend')

# %% [markdown]
# ### Quarterly Sales Trend

# %%
grouped_df = df_Store.groupby('quarter_year')
df_Store.groupby('quarter_year')['sales'].sum().sort_values(ascending=False)
# Out:
# quarter_year
# 2017Q3    3133059
# 2017Q2    3024172
# 2016Q3    3017043
# 2016Q2    2913344
# 2015Q3    2781083
# 2015Q2    2688553
# 2014Q3    2659730
# 2014Q2    2578633
# 2017Q4    2515167
# 2016Q4    2418496
# 2013Q3    2312590
# 2013Q2    2241113
# 2015Q4    2232470
# 2014Q4    2137714
# 2017Q1    2061342
# 2016Q1    2008277
# 2013Q4    1855837
# 2015Q1    1834781
# 2014Q1    1759405
# 2013Q1    1531703
# Freq: Q-DEC, Name: sales, dtype: int64

# %%
#plt.figure(figsize = (12, 6))
df_Store.groupby('quarter_year')['sales'].sum().sort_values(ascending=False).plot(kind='bar', cmap='Accent', figsize = (12, 6))

plt.xlabel('quarter_year', fontweight="bold", fontsize=14)
plt.ylabel('sales', fontweight="bold", fontsize=14)
plt.title('YoY Quarterly Sales trend', fontweight="bold", fontsize=18)
# Out:
# Text(0.5, 1.0, 'YoY Quarterly Sales trend')

# %% [markdown]
# ### Top 10 Most Expensive Items Sold

# %%
df_Store.groupby('item')['sales'].sum().sort_values(ascending=False)[:10]
# Out:
# item
# 15    1607442
# 28    1604713
# 13    1539621
# 18    1538876
# 25    1473334
# 45    1471467
# 38    1470330
# 22    1469971
# 36    1406548
# 8     1405108
# Name: sales, dtype: int64

# %%
df_Store.groupby('item')['sales'].sum().sort_values(ascending=False)[:10].plot(kind='bar', cmap='Set1', figsize = (12, 6))

plt.xlabel('Items', fontweight="bold", fontsize=14)
plt.ylabel('Sales', fontweight="bold", fontsize=14)
plt.title('Top 10 Most Expensive Items Sold', fontweight="bold", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Top 10 Most Expensive Items Sold')

# %% [markdown]
# - Most expensive items sold were Item# 15 & 28 for total 16mn each.

# %% [markdown]
# ### Which Store has the highest Sales?

# %%
df_Store.groupby('store')['sales'].mean().sort_values(ascending=False)
# Out:
# store
# 2     67.033165
# 8     64.142048
# 3     59.530602
# 10    58.709288
# 9     55.049025
# 4     54.902946
# 1     47.268379
# 5     39.770164
# 6     39.733516
# 7     36.363735
# Name: sales, dtype: float64

# %%
#Which Store has the highest Sales?
df_Store.groupby('store')['sales'].mean().sort_values(ascending=False).plot(kind='bar', cmap='tab20b', figsize = (12, 6))

plt.xlabel('Stores', fontweight="bold", fontsize=14)
plt.ylabel('Sales', fontweight="bold", fontsize=14)
plt.title('Highest Store Sales', fontweight="bold", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Highest Store Sales')

# %% [markdown]
# - Store# 2 recorded highest sales with average sales of 67.03mn.

# %% [markdown]
# ### How many items were sold in each Quarter/Year?

# %%
#How many items were sold in each Quarter/Year? 
df_Store.groupby('quarter_year')['item'].count().sort_values(ascending=False)
# Out:
# quarter_year
# 2017Q4    46000
# 2014Q4    46000
# 2013Q3    46000
# 2016Q4    46000
# 2016Q3    46000
# 2013Q4    46000
# 2015Q4    46000
# 2015Q3    46000
# 2017Q3    46000
# 2014Q3    46000
# 2013Q2    45500
# 2014Q2    45500
# 2015Q2    45500
# 2016Q1    45500
# 2016Q2    45500
# 2017Q2    45500
# 2015Q1    45000
# 2014Q1    45000
# 2017Q1    45000
# 2013Q1    45000
# Freq: Q-DEC, Name: item, dtype: int64

# %%
#df_mcd.plot(kind='hexbin', x='Serve_Size', y='Energy', figsize=(15, 7), gridsize=25, fontsize=13, colormap='Reds')
df_Store.groupby('quarter_year')['item'].count().sort_values(ascending=False).plot(kind='bar',yticks=np.arange(0, 50000, 15500),
                                                                                   cmap='GnBu_r', figsize = (12, 6))

plt.xlabel('YoY Quarter', fontweight="bold", fontsize=14)
plt.ylabel('Items', fontweight="bold", fontsize=14)
plt.title('Items sold YoY Quarter', fontweight="bold", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Items sold YoY Quarter')

# %% [markdown]
# ### Total selling Price of each item

# %%
#Total selling Price of each item

df_Store.groupby(['item'])['sales'].mean().sort_values()
# Out:
# item
# 5     18.358708
# 1     21.981599
# 41    22.002136
# 47    22.003341
# 4     22.010241
# 27    22.049726
# 16    25.656079
# 34    25.735761
# 40    29.249398
# 37    29.258379
# 23    29.297864
# 49    29.335323
# 44    29.398193
# 17    32.994852
# 3     36.642223
# 42    36.688116
# 21    40.317087
# 30    40.337021
# 19    40.355531
# 39    43.883406
# 32    43.981763
# 20    47.515936
# 26    47.644085
# 43    51.294359
# 48    51.352848
# 9     51.389869
# 6     58.503888
# 7     58.531051
# 2     58.574151
# 46    58.639869
# 31    58.644304
# 14    58.681873
# 35    65.801807
# 50    65.882202
# 24    66.044633
# 33    69.560953
# 29    69.618839
# 12    69.634940
# 11    69.656353
# 10    73.227437
# 8     76.950055
# 36    77.028916
# 22    80.502245
# 38    80.521906
# 45    80.584173
# 25    80.686418
# 18    84.275794
# 13    84.316594
# 28    87.881325
# 15    88.030778
# Name: sales, dtype: float64

# %%
#Total selling Price of each item

df_Store.groupby(['item'])['sales'].mean().sort_values().plot(kind='bar', figsize=(15,7), fontsize=13, 
                                                                          color='green')
plt.ylabel('Total Selling Price')
plt.xlabel('Items')
# Out:
# Text(0.5, 0, 'Items')

# %% [markdown]
# - Out of total selling price of each item, most expensive items, **item#15** was sold at **USD 88.03/-** and **item#28** at **USD 87.88/-**
#
# - **Cheapest item** sold was **item#5** at **USD 18/-**

# %% [markdown]
# ### How many items were sold every year?

# %%
df_Store.groupby('item')['sales'].count().sort_values(ascending=False)[:10]
# Out:
# item
# 50    18260
# 13    18260
# 23    18260
# 22    18260
# 21    18260
# 20    18260
# 19    18260
# 18    18260
# 17    18260
# 16    18260
# Name: sales, dtype: int64

# %% [markdown]
# - Items sold every year was uniform.

# %%
df_Store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          913000 non-null  object
#  1   store         913000 non-null  int64
#  2   item          913000 non-null  int64
#  3   sales         913000 non-null  int64
#  4   year          913000 non-null  int64
#  5   quarter_year  913000 non-null  period[Q-DEC]
#  6   month_year    913000 non-null  period[M]
# dtypes: int64(4), object(1), period[M](1), period[Q-DEC](1)
# memory usage: 48.8+ MB

# %% [markdown]
# ## Time Series Analysis

# %%
df_Store.head()
# Out:
#          date  store  item  sales  year quarter_year month_year
# 0  2013-01-01      1     1     13  2013       2013Q1    2013-01
# 1  2013-01-02      1     1     11  2013       2013Q1    2013-01
# 2  2013-01-03      1     1     14  2013       2013Q1    2013-01
# 3  2013-01-04      1     1     13  2013       2013Q1    2013-01
# 4  2013-01-05      1     1     10  2013       2013Q1    2013-01

# %%
#As we need to predict monthly sales, we will eliminate all unwanted columns and we will consolidate all store & sales into Total Montlhly Sales.

df_Store.drop(['year', 'quarter_year', 'month_year'], 1, inplace=True) #dropping columns used for EDA purpose not needed for prediction

# %%
df_Store.head()
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
def monthly_sales(data):
    monthly_data = data.copy()
    monthly_data.date = monthly_data.date.apply(lambda x: str(x)[:-3])
    monthly_data = monthly_data.groupby('date')['sales'].sum().reset_index()
    monthly_data.date = pd.to_datetime(monthly_data.date)
    return monthly_data

# %%
monthly_df = monthly_sales(df_Store)
monthly_df.head()
# Out:
#         date   sales
# 0 2013-01-01  454904
# 1 2013-02-01  459417
# 2 2013-03-01  617382
# 3 2013-04-01  682274
# 4 2013-05-01  763242

# %%
indexed_monthly_df  =  monthly_df.set_index(['date'])
indexed_monthly_df.head()
# Out:
#              sales
# date
# 2013-01-01  454904
# 2013-02-01  459417
# 2013-03-01  617382
# 2013-04-01  682274
# 2013-05-01  763242

# %% [markdown]
# ### Checking Trend Component

# %%
plt.xlabel('Yearl')
plt.ylabel('Sales')
plt.plot(indexed_monthly_df)

# %% [markdown]
# ### Decomposition

# %%
from matplotlib.pylab import rcParams
rcParams['figure.figsize']  =  10, 9

from statsmodels.tsa.seasonal import seasonal_decompose
decomposed_dataset  =  seasonal_decompose(indexed_monthly_df)         
figure  =  decomposed_dataset.plot()
plt.show()

# %% [markdown]
# ### Stationarity Check

# %% [markdown]
# Making a function to check stationarity in one go using both __rolling statistics plot and ADF test__.

# %%
def test_stationarity(time_series):
    rolling_means(time_series)
    adf_test(time_series)

# %% [markdown]
# #### Rolling Statistics Methodology

# %%
# Determine rolling statistics
def rolling_means(time_series):
    rolmean  =  time_series.rolling(window = 12).mean()    #window size 12 denotes 12 months, giving rolling mean at yearly level
    rolstd  =  time_series.rolling(window = 12).std()

    #Plot rolling statistics

    rcParams['figure.figsize']  =  10, 5 

    orig  =  plt.plot(time_series, color = 'blue', label = 'Original')
    mean  =  plt.plot(rolmean, color = 'red', label = 'Rolling Mean')
    std  =  plt.plot(rolstd, color = 'black', label = 'Rolling Std')
    plt.legend(loc = 'best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block = False)

# %%
rolling_means(indexed_monthly_df)

# %% [markdown]
# *Observation*
#
# - Rolling mean has a __trend__ component
# - Rolling standard deviation is fairly __constant__ with time.
#
# For our time series to be stationary, we need to ensure that both the __rolling statistics__ i.e: __mean & stdandard deviation remain time invariant__ or constant with time. Thus the curves for both of them have to be parallel to the x-axis, which in our case is not so.
#
# To further augment our hypothesis that the time series is not stationary, let us perform the __ADCF test__.

# %% [markdown]
# #### ADF(Augmented Dickey-Fuller) Test

# %% [markdown]
# For a Time series to be __stationary__, its ADF test should have:
# 1. __low p-value__ (according to the null hypothesis)
# 2. __Critical values__ at 1%, 5%, 10% confidence intervals should be as __close__ as possible __to__ the __Test Statistics__

# %%
#Perform Augmented Dickey–Fuller test:
def adf_test(time_series):
    from statsmodels.tsa.stattools import adfuller
    dftest  =  adfuller(time_series['sales'], autolag = 'AIC')

    dfoutput  =  pd.Series(dftest[0:4], index = ['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key]  =  value
    
    print('Results of Dickey Fuller Test:')    
    print(dfoutput)

# %%
adf_test(indexed_monthly_df)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                 -5.247519
# p-value                         0.000007
# #Lags Used                     11.000000
# Number of Observations Used    48.000000
# Critical Value (1%)            -3.574589
# Critical Value (5%)            -2.923954
# Critical Value (10%)           -2.600039
# dtype: float64

# %% [markdown]
# *Observation* -
# - **Low p-value**
# - **Critical values (1%, 5%, 10%)** are **not close** to the **Test Statistics**.
#
# Though the p-value is low here, the critical values are not close to the Test Statistics.<br>
# Hence, we can say that **our Time Series at the moment is not stationary**

# %% [markdown]
# ### Data Transformation to achieve Stationarity

# %% [markdown]
# #### Log Scale Transformation

# %%
import numpy as np
monthly_df_logScale  =  np.log(indexed_monthly_df)
rcParams['figure.figsize']  =  10, 5
plt.plot(monthly_df_logScale)

# %%
test_stationarity(monthly_df_logScale)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                -7.023527e+00
# p-value                        6.451513e-10
# #Lags Used                     1.100000e+01
# Number of Observations Used    4.800000e+01
# Critical Value (1%)           -3.574589e+00
# Critical Value (5%)           -2.923954e+00
# Critical Value (10%)          -2.600039e+00
# dtype: float64

# %% [markdown]
# From above graph, we see that even though rolling mean is not stationary, it is still better than the previous case, where no transfromation were applied to series.

# %% [markdown]
# #### Log Scale - Moving Average Transformation

# %%
movingAverage  =  monthly_df_logScale.rolling(window = 12).mean()
datasetLogScaleMinusMovingAverage  =  monthly_df_logScale - movingAverage
plt.plot(datasetLogScaleMinusMovingAverage)

#Remove NAN values
datasetLogScaleMinusMovingAverage.dropna(inplace = True)

# %%
test_stationarity(datasetLogScaleMinusMovingAverage)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                 -2.906158
# p-value                         0.044637
# #Lags Used                     11.000000
# Number of Observations Used    37.000000
# Critical Value (1%)            -3.620918
# Critical Value (5%)            -2.943539
# Critical Value (10%)           -2.610400
# dtype: float64

# %% [markdown]
# p-value is 0.044.
# The critical values at 1%,5%,10% confidence intervals are pretty close to the Test Statistic.
#
# Let's try Exponential Decay

# %% [markdown]
# #### Exponential Decay Transformation

# %%
exponentialDecayWeightedAverage  =  monthly_df_logScale.ewm(halflife = 12, min_periods = 0, adjust = True).mean()
plt.plot(monthly_df_logScale)
plt.plot(exponentialDecayWeightedAverage, color = 'red')

# %%
test_stationarity(exponentialDecayWeightedAverage)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                 -1.850556
# p-value                         0.355666
# #Lags Used                     10.000000
# Number of Observations Used    49.000000
# Critical Value (1%)            -3.571472
# Critical Value (5%)            -2.922629
# Critical Value (10%)           -2.599336
# dtype: float64

# %% [markdown]
# From above graph, it seems that exponential decay is not holding any advantage over log scale as both the corresponding curves are similar.

# %%
datasetLogScaleMinusExponentialMovingAverage  =  monthly_df_logScale - exponentialDecayWeightedAverage
test_stationarity(datasetLogScaleMinusExponentialMovingAverage)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                 -1.320423
# p-value                         0.619778
# #Lags Used                     11.000000
# Number of Observations Used    48.000000
# Critical Value (1%)            -3.574589
# Critical Value (5%)            -2.923954
# Critical Value (10%)           -2.600039
# dtype: float64

# %% [markdown]
# We observe that the Time Series is stationary & also the series for moving avg & std. dev. is almost parallel to x-axis thus they also have no trend.
#
# Though, **p-value is 0.619**, **Test Statistic value** is slightly closer to the Critical values.

# %% [markdown]
# #### Time Shift Transformation

# %%
datasetLogDiffShifting  =  monthly_df_logScale - monthly_df_logScale.shift()
plt.plot(datasetLogDiffShifting)

# %%
datasetLogDiffShifting.dropna(inplace = True)

test_stationarity(datasetLogDiffShifting)
# Out:
# Results of Dickey Fuller Test:
# Test Statistic                 -1.767584
# p-value                         0.396670
# #Lags Used                     11.000000
# Number of Observations Used    47.000000
# Critical Value (1%)            -3.577848
# Critical Value (5%)            -2.925338
# Critical Value (10%)           -2.600774
# dtype: float64

# %% [markdown]
# From above 2 graphs, we can see that, visually this is the best result as our series along with rolling statistic values of moving avg & moving std. dev. is very much flat & stationary.
#
# But, the ADCF test shows us that:
#
# p-value of 0.39 is not as good as 0.04 of datasetLogScaleMinusMovingAverage.
# Test Statistic value not as close to the critical values as that for exponential decay.
# We have thus tried out 3 different transformation: log, exp decay & time shift. We will go ahead with the timeshifted dataset.

# %%
#ACF & PACF plots

from statsmodels.tsa.stattools import acf, pacf

lag_acf  =  acf(datasetLogDiffShifting, nlags = 20)
lag_pacf  =  pacf(datasetLogDiffShifting, nlags = 20, method = 'ols')
rcParams['figure.figsize']  =  10, 5

#Plot ACF:
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y = 0, linestyle = '--', color = 'gray')
plt.axhline(y = -1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle = '--', color = 'gray')
plt.axhline(y = 1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle = '--', color = 'gray')
plt.xticks(np.arange(0,22,2))
plt.title('Autocorrelation Function')            


#Plot PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y = 0, linestyle = '--', color = 'gray')
plt.axhline(y = -1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle = '--', color = 'gray')
plt.axhline(y = 1.96/np.sqrt(len(datasetLogDiffShifting)), linestyle = '--', color = 'gray')
plt.xticks(np.arange(0,22,2))
plt.title('Partial Autocorrelation Function')
            
plt.tight_layout()

# %% [markdown]
# From the __ACF graph__,
# - Curve touches y = 0.0 line at x = 3. Thus, __Q  =  3__
#
#
# From the __PACF graph__,
# - Curve touches y = 0.0 line at x = 3. Thus, __P  =  3__
#
# ARIMA is AR + I + MA. Before, we see an ARIMA model, let us check the results of the individual AR & MA model. Note that, these models will give a value of RSS. Lower RSS values indicate a better model.

# %% [markdown]
# ## Building Models

# %% [markdown]
# Let us forecaste deploying AR, ARMA and ARIMA model.

# %% [markdown]
# ### AR Model

# %% [markdown]
# - Using AR model to forecast the Sales for __3 months__.
# - Dividing the dataset into __train and test__. Keeping last 3 months data for testing the performance of our time series model.

# %%
datasetLogDiffShifting.head()
# Out:
#                sales
# date
# 2013-02-01  0.009872
# 2013-03-01  0.295530
# 2013-04-01  0.099943
# 2013-05-01  0.112144
# 2013-06-01  0.041518

# %%
# Data Preparation
train, test = datasetLogDiffShifting[1:len(datasetLogDiffShifting)-3], datasetLogDiffShifting[len(datasetLogDiffShifting)-3:]
train.head()
# Out:
#                sales
# date
# 2013-03-01  0.295530
# 2013-04-01  0.099943
# 2013-05-01  0.112144
# 2013-06-01  0.041518
# 2013-07-01  0.073086

# %%
test.head()
# Out:
#                sales
# date
# 2017-10-01 -0.048304
# 2017-11-01  0.041409
# 2017-12-01 -0.289777

# %% [markdown]
# - Deploying the autoregression model of __statsmodels library__ provided in the ar_model class.
# - It automatically selects an appropriate lag value using statistical tests and trains a linear regression model.

# %%
from statsmodels.tsa.ar_model import AR
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# Out:
# Lag: 10
# Coefficients: const        0.036577
# L1.sales    -0.331879
# L2.sales    -0.347943
# L3.sales    -0.667157
# L4.sales    -0.298113
# L5.sales    -0.514705
# L6.sales    -0.432854
# L7.sales    -0.647754
# L8.sales    -0.265060
# L9.sales    -0.546021
# L10.sales   -0.580198
# dtype: float64
# C:\Users\vins_\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %% [markdown]
# - Observe that a __10-lag model__ was chosen and trained. This is interesting given how close this lag is to the number of months in a year.

# %% [markdown]
# - __Forecasting__ using the developed model and printing out the __3 month forecast__.

# %%
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
predictions.head()
for i in range(len(predictions)):
    print('predicted=%f, expected=%f' % (predictions[i], test.iloc[i]))
# Out:
# predicted=-0.035875, expected=-0.048304
# predicted=-0.039115, expected=0.041409
# predicted=-0.150146, expected=-0.289777

# %% [markdown]
# - __Model evaluation__ using Mean_squared_error

# %%
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot results

pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Test MSE: 0.009

# %% [markdown]
# MSE error score 0.009

# %%
plt.plot(train)
plt.plot(model_fit.fittedvalues, color = 'red')
print('Plotting AR model')
# Out:
# Plotting AR model

# %% [markdown]
# ### ARMA Model

# %%
from statsmodels.tsa.arima_model import ARMA
model = ARMA(train,order=(2,2))
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# Out:
# C:\Users\vins_\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# Lag: 2
# Coefficients: const          0.006009
# ar.L1.sales    1.596542
# ar.L2.sales   -0.866310
# ma.L1.sales   -1.999930
# ma.L2.sales    0.999930
# dtype: float64
# C:\Users\vins_\anaconda3\lib\site-packages\statsmodels\base\model.py:548: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)
# C:\Users\vins_\anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# - Observe that a __2-lag model__ was chosen and trained.

# %% [markdown]
# - __Forecasting__ using the developed model and printing out the __3 month forecast__.

# %%
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
for i in range(len(predictions)):
    print('predicted=%f, expected=%f' % (predictions[i], test.iloc[i]))
# Out:
# predicted=-0.059909, expected=-0.048304
# predicted=-0.044666, expected=0.041409
# predicted=-0.017791, expected=-0.289777

# %% [markdown]
# - __Model evaluation__ using Mean_squared_error

# %%
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot results

pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Test MSE: 0.027

# %% [markdown]
# MSE is more than that obtained with AR model. <br/>
# Observing the plot of <span style="color:blue">**__expected__** </span> vs the <span style="color:red">**__predicted__** </span>.
# The forecast doesnt look good with large deviation at 3 and 5.

# %%
plt.plot(train)
plt.plot(model_fit.fittedvalues, color = 'red')
print('Plotting ARMA model')
# Out:
# Plotting ARMA model

# %%
plot = model_fit.plot_predict()

# %% [markdown]
# ### ARIMA Model

# %% [markdown]
# - Training ARIMA model with __stationary__ made dataset "datasetLogDiffShifting" using the (p,d,q) = __(2,0,2)__.
# - p and q values are chosen considering observations of ACF and PACF plots.

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(datasetLogDiffShifting,order=(2,0,2))
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# Out:
# Lag: 2
# Coefficients: const          0.006009
# ar.L1.sales    1.596542
# ar.L2.sales   -0.866310
# ma.L1.sales   -1.999930
# ma.L2.sales    0.999930
# dtype: float64
# C:\Users\vins_\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)

# %% [markdown]
# - Observe that a __2-lag model__ was chosen and trained.

# %% [markdown]
# - __Model evaluation__ using Mean_squared_error

# %%
results_ARIMA = model.fit()

# %%
from sklearn.metrics import mean_squared_error
from matplotlib import pyplot
error = mean_squared_error(datasetLogDiffShifting, results_ARIMA.fittedvalues)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 0.012

# %%
results_ARIMA.fittedvalues.head()
# Out:
# date
# 2013-02-01    0.006705
# 2013-03-01    0.007364
# 2013-04-01    0.063287
# 2013-05-01    0.054031
# 2013-06-01   -0.028498
# dtype: float64

# %%
fitted_values = results_ARIMA.plot_predict()

# %% [markdown]
# ### Prediction & Reverse transformations of fittedvalues

# %%
predictions_ARIMA_diff = pd.Series(results_ARIMA.fittedvalues, copy=True)
predictions_ARIMA_diff.head()
# Out:
# date
# 2013-02-01    0.006705
# 2013-03-01    0.007364
# 2013-04-01    0.063287
# 2013-05-01    0.054031
# 2013-06-01   -0.028498
# dtype: float64

# %%
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
predictions_ARIMA_diff_cumsum.head()
# Out:
# date
# 2013-02-01    0.006705
# 2013-03-01    0.014069
# 2013-04-01    0.077356
# 2013-05-01    0.131387
# 2013-06-01    0.102889
# dtype: float64

# %%
predictions_ARIMA_log = pd.Series(monthly_df_logScale['sales'].iloc[0], index=datasetLogDiffShifting.index)
predictions_ARIMA_log = predictions_ARIMA_log.add(predictions_ARIMA_diff_cumsum,fill_value=0)
predictions_ARIMA_log.head()
# Out:
# date
# 2013-02-01    13.034547
# 2013-03-01    13.041911
# 2013-04-01    13.105198
# 2013-05-01    13.159229
# 2013-06-01    13.130731
# dtype: float64

# %%
reverted_back_prediction = pd.DataFrame(np.exp(predictions_ARIMA_log))
reverted_back_prediction.head()
# Out:
#                         0
# date
# 2013-02-01  457964.412150
# 2013-03-01  461349.285317
# 2013-04-01  491490.522137
# 2013-05-01  518776.663863
# 2013-06-01  504201.205942

# %%
from matplotlib import pyplot
pyplot.plot(indexed_monthly_df)
pyplot.plot(reverted_back_prediction, color='red')
pyplot.show()

# %%
monthly_df_logScale.columns = ['Sales in logscale']
reverted_back_prediction.columns = ['ARIMA Predicted Sales']
datasetLogDiffShifting.columns = ['Sales after log diff shifting']

# %%
df = pd.concat([indexed_monthly_df,monthly_df_logScale, datasetLogDiffShifting,reverted_back_prediction], axis=1, sort=False)
df.tail()
# Out:
#               sales  Sales in logscale  Sales after log diff shifting  \
# date
# 2017-08-01  1026403          13.841571                      -0.132133
# 2017-09-01   935263          13.748583                      -0.092988
# 2017-10-01   891160          13.700279                      -0.048304
# 2017-11-01   928837          13.741689                       0.041409
# 2017-12-01   695170          13.451912                      -0.289777
#
#             ARIMA Predicted Sales
# date
# 2017-08-01          727507.766515
# 2017-09-01          742212.878619
# 2017-10-01          652969.549130
# 2017-11-01          744922.416062
# 2017-12-01          658344.403295

# %% [markdown]
# ## Conclusion
#
# We see that our predicted forecasts are fairly close to the real time series values indicating a fairly accurate model.

# %% [markdown]
# --continued in another notebook...refer Store & Item level sales prediction.
